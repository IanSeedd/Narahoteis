# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('narahoteisbases/clientes.csv', sep=';')
df
# Out:
#      id_cliente                nome   cidade_origem estado_origem  \
# 0             1         Otavio Reis       São Paulo            SP
# 1             2       Larissa Sousa        Curitiba            SC
# 2             3      Tatiana Coelho  Rio de Janeiro            CE
# 3             4       Wilson Duarte        Brasília            AM
# 4             5       Gabriela Lima  Rio de Janeiro            SP
# ..          ...                 ...             ...           ...
# 296         297       Roberta Leite        Curitiba            DF
# 297         298       Eduardo Lopes       São Paulo            ES
# 298         299  Vanessa Cavalcanti        Curitiba            AM
# 299         300     Julia Monteiro         Brasília            PR
# 300          47         Carlos Neto         Niterói            RJ
#
#     faixa_etaria   tipo_cliente
# 0          18-25             PJ
# 1          18-25  pessoa fisica
# 2            65+    Corporativo
# 3          26-35    corporativo
# 4          46-55  Pessoa Física
# ..           ...            ...
# 296        56-65  pessoa fisica
# 297        36-45             PJ
# 298        46-55  Pessoa Física
# 299        36-45    Corporativo
# 300        36-45    Corporativo
#
# [301 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_cliente     301 non-null    int64
#  1   nome           301 non-null    str
#  2   cidade_origem  301 non-null    str
#  3   estado_origem  301 non-null    str
#  4   faixa_etaria   272 non-null    str
#  5   tipo_cliente   301 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 14.2 KB

# %% [markdown]
# ### Tratamento cidade origem

# %%
df['cidade_origem'] = df['cidade_origem'].str.strip().str.title().str.replace('De', 'de', regex=False) # Caso especial apenas para que fique Rio de Janeiro invés de Rio De Janeiro
df.head(10)
# Out:
#    id_cliente            nome   cidade_origem estado_origem faixa_etaria  \
# 0           1     Otavio Reis       São Paulo            SP        18-25
# 1           2   Larissa Sousa        Curitiba            SC        18-25
# 2           3  Tatiana Coelho  Rio de Janeiro            CE          65+
# 3           4   Wilson Duarte        Brasília            AM        26-35
# 4           5   Gabriela Lima  Rio de Janeiro            SP        46-55
# 5           6   Ulisses Brito        Brasília            RS        56-65
# 6           7    Kleber Pires       São Paulo            ES          65+
# 7           8  Olivia Freitas        Brasília            PA        18-25
# 8           9   Wesley Araujo  Belo Horizonte            ES          NaN
# 9          10    Ivan Azevedo        Curitiba            PE        26-35
#
#     tipo_cliente
# 0             PJ
# 1  pessoa fisica
# 2    Corporativo
# 3    corporativo
# 4  Pessoa Física
# 5  Pessoa Física
# 6  pessoa fisica
# 7    Corporativo
# 8    Corporativo
# 9             pf

# %%
df['cidade_origem'].value_counts().reset_index()
# Out:
#     cidade_origem  count
# 0       Fortaleza     46
# 1       São Paulo     41
# 2          Recife     41
# 3        Curitiba     39
# 4        Salvador     36
# 5  Belo Horizonte     33
# 6  Rio de Janeiro     32
# 7        Brasília     32
# 8         Niterói      1

# %% [markdown]
# ### Tratamento tipo de cliente

# %%
df['tipo_cliente'] = df['tipo_cliente'].str.strip().str.title()
map_cliente = {
    'Pf': 'Pessoa Física',
    'Pessoa Fisica': 'Pessoa Física',
    'Pj': 'Corporativo'
}
df['tipo_cliente'] = df['tipo_cliente'].map(map_cliente).fillna(df['tipo_cliente'])

# %%
df['tipo_cliente'].value_counts().reset_index()
# Out:
#     tipo_cliente  count
# 0    Corporativo    159
# 1  Pessoa Física    142

# %% [markdown]
# ### Tratamento de nome

# %%
df['nome'] = df['nome'].str.strip().str.title()

# %%
mascara = df['nome'].str.startswith(' ') | df['nome'].str.endswith(' ')
df.loc[mascara, 'nome'].tolist()
# Out:
# []

# %% [markdown]
# ### Nulos e POSSÍVEIS duplicatas

# %%
df.isnull().sum().reset_index()
# Out:
#            index   0
# 0     id_cliente   0
# 1           nome   0
# 2  cidade_origem   0
# 3  estado_origem   0
# 4   faixa_etaria  29
# 5   tipo_cliente   0

# %%
df[df.duplicated(subset=['nome', 'cidade_origem', 'faixa_etaria'], keep=False)].sort_values(by='nome')
# Out:
#      id_cliente            nome   cidade_origem   estado_origem faixa_etaria  \
# 30           31    Abel Correia  Rio de Janeiro              RS        46-55
# 57           58    Abel Correia  Rio de Janeiro              CE        46-55
# 194         195     Carlos Neto       Fortaleza              DF        36-45
# 66           67     Carlos Neto        Salvador              BA        26-35
# 85           86     Carlos Neto       Fortaleza              ES        46-55
# 184         185     Carlos Neto       Fortaleza              SP        36-45
# 152         153     Carlos Neto        Salvador              GO        26-35
# 253         254     Carlos Neto       Fortaleza              PR        46-55
# 37           38   Daniela Ramos       São Paulo              PR        18-25
# 153         154   Daniela Ramos       São Paulo              CE        18-25
# 144         145   Fernanda Cruz        Curitiba              DF        46-55
# 241         242   Fernanda Cruz        Curitiba              BA        46-55
# 247         248  Gustavo Vieira       Fortaleza  Rio de Janeiro        18-25
# 110         111  Gustavo Vieira       Fortaleza              PA        18-25
# 255         256   Helena Borges        Salvador              SC        36-45
# 136         137   Helena Borges        Salvador              GO        36-45
# 112         113  Henrique Rocha          Recife              RJ          NaN
# 14           15  Henrique Rocha          Recife              MG          NaN
# 202         203    João Pereira  Rio de Janeiro              GO          65+
# 252         253    João Pereira  Rio de Janeiro              PA          65+
# 162         163  Olivia Freitas        Curitiba              PA        18-25
# 24           25  Olivia Freitas        Curitiba              SP        18-25
# 93           94  Rafael Cardoso       Fortaleza              RJ        18-25
# 43           44  Rafael Cardoso       Fortaleza              RJ        18-25
# 224         225   Roberta Leite        Salvador              PA        36-45
# 16           17   Roberta Leite        Salvador              GO        36-45
# 209         210    Ximena Godoi       Fortaleza              CE          NaN
# 228         229    Ximena Godoi       Fortaleza              SC          NaN
#
#       tipo_cliente
# 30   Pessoa Física
# 57   Pessoa Física
# 194    Corporativo
# 66     Corporativo
# 85     Corporativo
# 184  Pessoa Física
# 152  Pessoa Física
# 253  Pessoa Física
# 37   Pessoa Física
# 153  Pessoa Física
# 144    Corporativo
# 241  Pessoa Física
# 247  Pessoa Física
# 110    Corporativo
# 255  Pessoa Física
# 136  Pessoa Física
# 112  Pessoa Física
# 14   Pessoa Física
# 202    Corporativo
# 252  Pessoa Física
# 162    Corporativo
# 24     Corporativo
# 93     Corporativo
# 43     Corporativo
# 224    Corporativo
# 16     Corporativo
# 209    Corporativo
# 228  Pessoa Física

# %%
df[df.isnull() 
.any(axis=1)]
# Out:
#      id_cliente             nome   cidade_origem estado_origem faixa_etaria  \
# 8             9    Wesley Araujo  Belo Horizonte            ES          NaN
# 14           15   Henrique Rocha          Recife            MG          NaN
# 15           16   Marcos Andrade       São Paulo            RS          NaN
# 19           20     Thiago Matos       Fortaleza            ES          NaN
# 28           29  Isabela Martins       São Paulo            SC          NaN
# 38           39     Ivan Azevedo        Curitiba            ES          NaN
# 42           43    Roberta Leite          Recife            CE          NaN
# 52           53      Bruno Costa          Recife            SP          NaN
# 68           69  Isabela Martins          Recife            MG          NaN
# 92           93    Gabriela Lima  Belo Horizonte            PA          NaN
# 95           96     Quezia Nunes  Rio de Janeiro            PA          NaN
# 99          100      Otavio Reis  Rio de Janeiro            ES          NaN
# 107         108   Rafael Cardoso        Brasília            MG          NaN
# 112         113   Henrique Rocha          Recife            RJ          NaN
# 121         122        Ana Silva        Salvador            PE          NaN
# 123         124     Ursula Pinto        Salvador            CE          NaN
# 142         143   Henrique Rocha  Belo Horizonte            MG          NaN
# 165         166     Kleber Pires        Curitiba            CE          NaN
# 172         173     Elena Santos        Brasília            SC          NaN
# 174         175     Ursula Pinto       São Paulo            MG          NaN
# 181         182     Thiago Matos       São Paulo            RS          NaN
# 188         189     Thiago Matos          Recife            CE          NaN
# 199         200   Gustavo Vieira       São Paulo            PR          NaN
# 201         202    Wilson Duarte        Curitiba            PE          NaN
# 204         205      Otavio Reis        Brasília            GO          NaN
# 209         210     Ximena Godoi       Fortaleza            CE          NaN
# 228         229     Ximena Godoi       Fortaleza            SC          NaN
# 269         270      Lucas Souza       São Paulo            DF          NaN
# 295         296      Carlos Neto          Recife            PA          NaN
#
#       tipo_cliente
# 8      Corporativo
# 14   Pessoa Física
# 15     Corporativo
# 19   Pessoa Física
# 28     Corporativo
# 38     Corporativo
# 42     Corporativo
# 52   Pessoa Física
# 68     Corporativo
# 92     Corporativo
# 95   Pessoa Física
# 99   Pessoa Física
# 107    Corporativo
# 112  Pessoa Física
# 121    Corporativo
# 123    Corporativo
# 142  Pessoa Física
# 165  Pessoa Física
# 172  Pessoa Física
# 174    Corporativo
# 181  Pessoa Física
# 188    Corporativo
# 199    Corporativo
# 201    Corporativo
# 204  Pessoa Física
# 209    Corporativo
# 228  Pessoa Física
# 269    Corporativo
# 295  Pessoa Física
